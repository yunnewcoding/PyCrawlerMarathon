# %% [markdown]
# # Python 下載XML檔案與解析
#
#
# * 了解 xml 檔案格式與內容
# * 能夠利用套件存取 xml 格式的檔案

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異
#
# * 根據範例檔案的結果：
#     1. 請問高雄市有多少地區有溫度資料？
#     2. 請取出每一個地區所記錄的第一個時間點跟溫度
#     3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %% [markdown]
# ### 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異

# %%
# 使用 File I/O 開啟檔案
file=open("C:\\Users\\yun10\\Desktop\\爬蟲馬拉松\\Day003_example\\63_Week24_CH.xml", "r",encoding="utf-8")
f=file.read()
file.close()
print(f)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <cwbopendata xmlns="urn:cwb:gov:tw:cwbcommon:0.1">
#   <identifier>6c1f6aab-0782-43d8-ab5c-4711d8b7a866</identifier>
#   <sender>weather@cwb.gov.tw</sender>
#   <sent>2019-06-28T12:22:56+08:00</sent>
#   <status>Actual</status>
#   <scope>Public</scope>
#   <msgType>Issue</msgType>
#   <dataid>null</dataid>
#   <source>MFC</source>
#   <dataset>
#     <datasetInfo>
#       <datasetDescription>臺灣各縣市鄉鎮未來1週逐24小時天氣預報</datasetDescription>
#       <datasetLanguage>zh-TW</datasetLanguage>
#       <issueTime>2019-06-28T11:00:00+08:00</issueTime>
#       <validTime>
#         <startTime>2019-06-28T12:00:00+08:00</startTime>
#         <endTime>2019-07-06T11:00:00+08:00</endTime>
#       </validTime>
#       <update>2019-06-28T12:22:56+08:00</update>
#     </datasetInfo>
#     <locations>
#       <locationsName>臺北市</locationsName>
#       <location>
#         <locationName>松山區</locationName>
#         <geocode>6300100</geocode>
# ...

# %%
# 使用 xmltodict 開啟檔案
import xmltodict
with open("C:\\Users\\yun10\\Desktop\\爬蟲馬拉松\\Day003_example\\63_Week24_CH.xml",encoding="utf-8") as file:
    doc=dict(xmltodict.parse(file.read()))       # xmltodict.parse() 解析 xml 檔案並轉成字典
    print(doc)
# Out:
# {'cwbopendata': OrderedDict([('@xmlns', 'urn:cwb:gov:tw:cwbcommon:0.1'), ('identifier', '6c1f6aab-0782-43d8-ab5c-4711d8b7a866'), ('sender', 'weather@cwb.gov.tw'), ('sent', '2019-06-28T12:22:56+08:00'), ('status', 'Actual'), ('scope', 'Public'), ('msgType', 'Issue'), ('dataid', 'null'), ('source', 'MFC'), ('dataset', OrderedDict([('datasetInfo', OrderedDict([('datasetDescription', '臺灣各縣市鄉鎮未來1週逐24小時天氣預報'), ('datasetLanguage', 'zh-TW'), ('issueTime', '2019-06-28T11:00:00+08:00'), ('validTime', OrderedDict([('startTime', '2019-06-28T12:00:00+08:00'), ('endTime', '2019-07-06T11:00:00+08:00')])), ('update', '2019-06-28T12:22:56+08:00')])), ('locations', OrderedDict([('locationsName', '臺北市'), ('location', [OrderedDict([('locationName', '松山區'), ('geocode', '6300100'), ('lat', '25.051608'), ('lon', '121.568983'), ('weatherElement', [OrderedDict([('elementName', 'T'), ('description', '平均溫度'), ('time', [OrderedDict([('startTime', '2019-06-28T12:00:00+08:00'), ('endTime', '2019-06-29T00:00:00+08
# ...

# %% [markdown]
# ### 根據範例檔案的結果：
#
# 1. 請問高雄市有多少地區有溫度資料？
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %%
# 1. 請問高雄市有多少地區有溫度資料？
# 先試著找出檔案中包含哪些縣市
with open('C:\\Users\\yun10\\Desktop\\爬蟲馬拉松\\Day003_example\\TAIWAN_72hr_CH.xml', 'r', newline='', encoding='utf-8') as f:

    import xmltodict
    doc=xmltodict.parse(f.read())
    data=doc["cwbopendata"]["dataset"]["locations"]["location"]  # 用記事本打開 xml 找標籤會好找很多
    
    # 由於在 xml 中相同的標籤，在 xmltodict 轉換時會被轉成一個 list，例如 <location>標籤下的資料都會被收在一個 list 裡，所以在取值時要加上[...]的格式
    # 接下來一個一個印出資料中的縣市
    
    for i in range(len(data)):            # 從下一行倒著想回來，data裡共有 22 組資料，從 1 取到第 i 個縣市，所以用 for 一個一個取出來
        print(data[i]["locationName"])    # 取出 locationName 標籤下的第 i 個值

print("==============我是分隔線==================")        
        
# 根據問答區，高雄的檔案在 64_72hr_CH.xml 
 
with open('C:\\Users\\yun10\\Desktop\\爬蟲馬拉松\\Day003_example\\64_72hr_CH.xml ', 'r', newline='', encoding='utf-8') as k:
        doc=xmltodict.parse(k.read())
        area=doc["cwbopendata"]["dataset"]["locations"]["location"]
        print(len(area))
# Out:
#   File "<ipython-input-1-05f5a4d678ec>", line 15
#     print("==============我是分隔線==================")
#                                                           ^
# IndentationError: expected an indented block

# %%
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
with open('C:\\Users\\yun10\\Desktop\\爬蟲馬拉松\\Day003_example\\64_72hr_CH.xml ', 'r', newline='', encoding='utf-8') as k:
    import xmltodict
    doc=xmltodict.parse(k.read())
    data=doc["cwbopendata"]["dataset"]["locations"]["location"]
    print(type(data))      # 得知 ["location"] 之後是 list，不是 dict 了，所以沒辦法再["weatherelement"]往下取
    for location in data:               # 逐行讀取 data 中的資料
        # print(type(location))   得知資料型態為 dict
        # 需要的資料在 weatherElement 標籤下，用 print(type(location["weatherElement"])) 得知它是一個列表
        print(location["locationName"])   
        print(location["weatherElement"][0]["time"][0]["dataTime"])
        print(location["weatherElement"][0]["time"][0]["elementValue"]["value"])
# Out:
# <class 'list'>
# 鹽埕區
# 2019-06-28T12:00:00+08:00
# 33
# 鼓山區
# 2019-06-28T12:00:00+08:00
# 33
# 左營區
# 2019-06-28T12:00:00+08:00
# 33
# 楠梓區
# 2019-06-28T12:00:00+08:00
# 34
# 三民區
# 2019-06-28T12:00:00+08:00
# 32
# 新興區
# 2019-06-28T12:00:00+08:00
# 33
# 前金區
# 2019-06-28T12:00:00+08:00
# 33
# 苓雅區
# 2019-06-28T12:00:00+08:00
# 33
# 前鎮區
# 2019-06-28T12:00:00+08:00
# 33
# 旗津區
# 2019-06-28T12:00:00+08:00
# 32
# 小港區
# 2019-06-28T12:00:00+08:00
# 33
# 鳳山區
# 2019-06-28T12:00:00+08:00
# 34
# 林園區
# 2019-06-28T12:00:00+08:00
# 33
# 大寮區
# 2019-06-28T12:00:00+08:00
# 34
# 大樹區
# 2019-06-28T12:00:00+08:00
# 34
# 大社區
# 2019-06-28T12:00:00+08:00
# 34
# 仁武區
# 2019-06-28T12:00:00+08:00
# 33
# 鳥松區
# 2019-06-28T12:00:00+08:00
# 34
# 岡山區
# 2019-06-28T12:00:00+08:00
# 34
# 橋頭區
# 2019-06-28T12:00:00+08:00
# 35
# 燕巢區
# 2019-06-28T12:00:00+08:00
# 34
# 田寮區
# 2019-06-28T12:00:00+08:00
# 34
# 阿蓮區
# 2019-06-28T12:00:00+08:00
# 34
# 路竹區
# 2019-06-28T12:00:00+08:00
# 33
# 湖內區
# 2019-06-28T12:00:00+08:00
# 33
# 茄萣區
# ...

# %%
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度
with open('C:\\Users\\yun10\\Desktop\\爬蟲馬拉松\\Day003_example\\64_72hr_CH.xml ', 'r', newline='', encoding='utf-8') as k:
    import xmltodict
    doc=xmltodict.parse(k.read())
    data=doc["cwbopendata"]["dataset"]["locations"]["location"][0]   # 利用 print(type(data)) 得到 class 'list'
    print(data["locationName"])
    print(type(data["weatherElement"]))    # class 'list'
    for l in data["weatherElement"][0]['time']:
        print(l['dataTime'] )
        print(l['elementValue'])
# Out:
# 鹽埕區
# <class 'list'>
# 2019-06-28T12:00:00+08:00
# OrderedDict([('value', '33'), ('measures', '攝氏度')])
# 2019-06-28T15:00:00+08:00
# OrderedDict([('value', '33'), ('measures', '攝氏度')])
# 2019-06-28T18:00:00+08:00
# OrderedDict([('value', '32'), ('measures', '攝氏度')])
# 2019-06-28T21:00:00+08:00
# OrderedDict([('value', '30'), ('measures', '攝氏度')])
# 2019-06-29T00:00:00+08:00
# OrderedDict([('value', '30'), ('measures', '攝氏度')])
# 2019-06-29T03:00:00+08:00
# OrderedDict([('value', '29'), ('measures', '攝氏度')])
# 2019-06-29T06:00:00+08:00
# OrderedDict([('value', '28'), ('measures', '攝氏度')])
# 2019-06-29T09:00:00+08:00
# OrderedDict([('value', '31'), ('measures', '攝氏度')])
# 2019-06-29T12:00:00+08:00
# OrderedDict([('value', '32'), ('measures', '攝氏度')])
# 2019-06-29T15:00:00+08:00
# OrderedDict([('value', '32'), ('measures', '攝氏度')])
# 2019-06-29T18:00:00+08:00
# OrderedDict([('value', '31'), ('measures', '攝氏度')])
# 2019-06-29T21:00:00+08:00
# ...
